# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('titanic')

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# #we are making binning in age column

# %%
df.age.max()
# Out:
# 80.0

# %%
df.age.min()
# Out:
# 0.42

# %%
sns.histplot(df['age'])
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
#Binning of age column into 7 categories
bins = [0,1,5,12,18,30,50,80]
labels = ['Infants','Toddlers','Kids','Teens','Youngs','Middle_age','Old']
#Ab hum ny btana hy kis column ko bins mn convert krtna hai
pd.cut(df['age'], bins=bins, labels=labels)
# Out:
# 0          Youngs
# 1      Middle_age
# 2          Youngs
# 3      Middle_age
# 4      Middle_age
#           ...
# 886        Youngs
# 887        Youngs
# 888           NaN
# 889        Youngs
# 890    Middle_age
# Name: age, Length: 891, dtype: category
# Categories (7, object): ['Infants' < 'Toddlers' < 'Kids' < 'Teens' < 'Youngs' < 'Middle_age' < 'Old']

# %% [markdown]
# #Ab hum feature engineering karen gy aur column ko add karen gy

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# #Feature Engineering

# %%
bins = [0,1,5,12,18,30,50,80]
labels = ['Infants','Toddlers','Kids','Teens','Youngs','Middle_age','Old']
#Ab hum ny btana hy kis column ko bins mn convert krtna hai
df['binned_age'] = pd.cut(df['age'], bins=bins, labels=labels)

# %% [markdown]
# Ab yahan new column add ho gya hai

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone  binned_age
# 0    man        True  NaN  Southampton    no  False      Youngs
# 1  woman       False    C    Cherbourg   yes  False  Middle_age
# 2  woman       False  NaN  Southampton   yes   True      Youngs
# 3  woman       False    C  Southampton   yes  False  Middle_age
# 4    man        True  NaN  Southampton    no   True  Middle_age

# %%
df['binned_age'].value_counts()
# Out:
# Youngs        270
# Middle_age    241
# Teens          70
# Old            64
# Toddlers       30
# Kids           25
# Infants        14
# Name: binned_age, dtype: int64
